# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPRegressor

# Simulate data
np.random.seed(42)
X = np.linspace(0, 10, 1000)
Y = 4 + 3 * X - 0.7 * X**2 + 0.05 * X**3 + np.random.normal(scale=1.5, size=X.shape)  # Quadratic relationship with noise

# Define the MLPRegressor with a single hidden layer of 3 neurons and ReLU activation function
mlp = MLPRegressor(hidden_layer_sizes=(6,20), activation='relu', alpha=0, max_iter=1000000, solver='adam', learning_rate='adaptive')

# Fit the model to the data
mlp.fit(X.reshape(-1, 1), Y)

# Predict Y using the fitted model
Y_pred = mlp.predict(X.reshape(-1, 1))

# Plot the results
plt.figure(figsize=(10, 6))
plt.scatter(X, Y, color='blue', label='Data')
plt.plot(X, Y_pred, color='red', label='Neural Net', linewidth=2)
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Scatterplot with Neural Net Predictions')
plt.legend()
plt.show()

# View the weights (coefs) of the model
print("Weights between input and hidden layer:", mlp.coefs_[0])
print("Weights between first hidden and second hidden layer:", mlp.coefs_[1])
print("Weights between hidden and output layer:", mlp.coefs_[2])

# View the biases (intercepts) of the model
print("Biases of the hidden layer:", mlp.intercepts_[0])
print("Biases of the second hidden layer:", mlp.intercepts_[1])
print("Biases of the output layer:", mlp.intercepts_[2])
# Out:
# Weights between input and hidden layer: [[-0.61570262 -0.16589443  0.34477722  0.45584734 -0.50077076  1.04818919]]
# Weights between first hidden and second hidden layer: [[-0.15425127  0.30247419 -0.40341261  0.37932757  0.04572528  0.30484984
#   -0.04581111  0.13794499  0.02536686  0.22250402 -0.40195691 -0.42240005
#   -0.24297535 -0.32709889  0.3571981  -0.26977047  0.45719655 -0.15670545
#   -0.30541123  0.27833332]
#  [ 1.23041527  1.09242576  1.16836633  0.21060226  0.84175806  1.66190054
#    0.45616651  1.22079154 -0.28867028  0.15138581 -0.41101847  0.62726281
#   -0.28382488 -0.0359107   1.08580793  0.20079093  1.3042644  -1.97084668
#    0.96333588 -1.41864917]
#  [ 0.51004495 -0.40232672  0.38893333  0.07558889 -0.0030596   0.43855175
#   -0.01280807  0.40074678  0.3849819  -0.29618713 -0.21441692  0.13071486
#    0.34959258 -0.27798678  0.00917947 -0.11636567  0.2662782  -0.31882886
#    0.36402474  0.35825741]
# ...
